# %% [markdown]
# # Importing Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # Setting Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
draw_landmarks(frame, results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1b5405974159> in <cell line: 1>()
# ----> 1 draw_landmarks(frame, results)
#
# NameError: name 'frame' is not defined

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.right_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.55942708,  0.44603366, -0.75601828, ...,  0.22314009,
#         0.19813654, -0.04080623])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.55942708,  0.44603366, -0.75601828, ...,  0.22314009,
#         0.19813654, -0.04080623])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
import os
import numpy as np

DATA_PATH = os.path.join('D:\\ML_Project_Final\\MP_Data')

# Actions that we try to detect
actions = np.array(['call', 'police', 'me', 'help', 'iloveyou', 'hello', 'thankyou', 'bye', 'danger'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 0

for action in actions:
    # Create action folder if it doesn't exist
    action_dir = os.path.join(DATA_PATH, action)
    if not os.path.exists(action_dir):
        os.makedirs(action_dir)

    # Get next folder number
    existing_folders = os.listdir(action_dir)
    if existing_folders:
        max_folder = max([int(f) for f in existing_folders])
    else:
        max_folder = -1

    for sequence in range(start_folder, start_folder + no_sequences):
        # Increment folder number
        max_folder += 1

        # Create sequence folder
        seq_dir = os.path.join(action_dir, str(max_folder))
        os.makedirs(seq_dir)

        # Create frame files
        for frame_num in range(sequence_length):
            frame_path = os.path.join(seq_dir, str(frame_num) + '.npy')
            np.save(frame_path, np.random.rand(128, 128, 3))

print('Dataset created.')
# Out:
# Dataset created.

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)

                # NEW Apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120,200),
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'call': 0,
#  'police': 1,
#  'me': 2,
#  'help': 3,
#  'iloveyou': 4,
#  'hello': 5,
#  'thankyou': 6,
#  'bye': 7,
#  'danger': 8}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (270, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (270,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (270, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (14, 9)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from keras.regularizers import l2
from keras.layers import Dropout

# %%
log_dir = os.path.join('D:\\ML_Project_Final\\Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=255, callbacks=[tb_callback])
# Out:
# Epoch 1/255
# 8/8 [==============================] - 5s 70ms/step - loss: 6.4775 - categorical_accuracy: 0.1211
# Epoch 2/255
# 8/8 [==============================] - 1s 71ms/step - loss: 7.7842 - categorical_accuracy: 0.1289
# Epoch 3/255
# 8/8 [==============================] - 1s 72ms/step - loss: 2.3161 - categorical_accuracy: 0.1328
# Epoch 4/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.9850 - categorical_accuracy: 0.1914
# Epoch 5/255
# 8/8 [==============================] - 1s 70ms/step - loss: 1.9120 - categorical_accuracy: 0.2656
# Epoch 6/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.7431 - categorical_accuracy: 0.2578
# Epoch 7/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.5309 - categorical_accuracy: 0.3086
# Epoch 8/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.6620 - categorical_accuracy: 0.2773
# Epoch 9/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.4477 - categorical_accuracy: 0.4648
# Epoch 10/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.1367 - categorical_accuracy: 0.5430
# Epoch 11/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0304 - categorical_accuracy: 0.6367
# Epoch 12/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.9488 - categorical_accuracy: 0.5859
# Epoch 13/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.9360 - categorical_accuracy: 0.6016
# Epoch 14/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.0989 - categorical_accuracy: 0.5391
# Epoch 15/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.7925 - categorical_accuracy: 0.7148
# Epoch 16/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.2834 - categorical_accuracy: 0.4727
# Epoch 17/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.6573 - categorical_accuracy: 0.3672
# Epoch 18/255
# 8/8 [==============================] - 1s 73ms/step - loss: 1.7694 - categorical_accuracy: 0.3516
# Epoch 19/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.2231 - categorical_accuracy: 0.3438
# Epoch 20/255
# 8/8 [==============================] - 1s 73ms/step - loss: 1.4308 - categorical_accuracy: 0.3945
# Epoch 21/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.1559 - categorical_accuracy: 0.5469
# Epoch 22/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.7800 - categorical_accuracy: 0.7539
# Epoch 23/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6568 - categorical_accuracy: 0.7305
# Epoch 24/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6593 - categorical_accuracy: 0.7070
# Epoch 25/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6419 - categorical_accuracy: 0.7070
# Epoch 26/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.7455 - categorical_accuracy: 0.6641
# Epoch 27/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.4033 - categorical_accuracy: 0.8438
# Epoch 28/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3809 - categorical_accuracy: 0.8164
# Epoch 29/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3762 - categorical_accuracy: 0.8203
# Epoch 30/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3248 - categorical_accuracy: 0.8633
# Epoch 31/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2825 - categorical_accuracy: 0.8945
# Epoch 32/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3098 - categorical_accuracy: 0.8281
# Epoch 33/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2703 - categorical_accuracy: 0.8516
# Epoch 34/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2614 - categorical_accuracy: 0.8750
# Epoch 35/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2347 - categorical_accuracy: 0.8984
# Epoch 36/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1912 - categorical_accuracy: 0.9023
# Epoch 37/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1869 - categorical_accuracy: 0.9023
# Epoch 38/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3890 - categorical_accuracy: 0.8477
# Epoch 39/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3293 - categorical_accuracy: 0.8555
# Epoch 40/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2505 - categorical_accuracy: 0.8906
# Epoch 41/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2329 - categorical_accuracy: 0.9023
# Epoch 42/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1820 - categorical_accuracy: 0.9258
# Epoch 43/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1386 - categorical_accuracy: 0.9453
# Epoch 44/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1468 - categorical_accuracy: 0.9297
# Epoch 45/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1163 - categorical_accuracy: 0.9766
# Epoch 46/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1087 - categorical_accuracy: 0.9688
# Epoch 47/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1037 - categorical_accuracy: 0.9492
# Epoch 48/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2730 - categorical_accuracy: 0.9062
# Epoch 49/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3399 - categorical_accuracy: 0.8438
# Epoch 50/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2187 - categorical_accuracy: 0.8984
# Epoch 51/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1878 - categorical_accuracy: 0.9062
# Epoch 52/255
# 8/8 [==============================] - 1s 70ms/step - loss: 1.2155 - categorical_accuracy: 0.7070
# Epoch 53/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.9176 - categorical_accuracy: 0.6836
# Epoch 54/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6991 - categorical_accuracy: 0.7227
# Epoch 55/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.7161 - categorical_accuracy: 0.7266
# Epoch 56/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5204 - categorical_accuracy: 0.7578
# Epoch 57/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3991 - categorical_accuracy: 0.8633
# Epoch 58/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2689 - categorical_accuracy: 0.9141
# Epoch 59/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1764 - categorical_accuracy: 0.9531
# Epoch 60/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1486 - categorical_accuracy: 0.9766
# Epoch 61/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1213 - categorical_accuracy: 0.9688
# Epoch 62/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1513 - categorical_accuracy: 0.9414
# Epoch 63/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1487 - categorical_accuracy: 0.9570
# Epoch 64/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0743 - categorical_accuracy: 0.9766
# Epoch 65/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0422 - categorical_accuracy: 0.9883
# Epoch 66/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.4883 - categorical_accuracy: 0.8789
# Epoch 67/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3932 - categorical_accuracy: 0.8594
# Epoch 68/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2622 - categorical_accuracy: 0.8516
# Epoch 69/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1531 - categorical_accuracy: 0.9336
# Epoch 70/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1147 - categorical_accuracy: 0.9688
# Epoch 71/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1014 - categorical_accuracy: 0.9805
# Epoch 72/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0712 - categorical_accuracy: 0.9844
# Epoch 73/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0557 - categorical_accuracy: 0.9883
# Epoch 74/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0258 - categorical_accuracy: 0.9883
# Epoch 75/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0502 - categorical_accuracy: 0.9883
# Epoch 76/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1396 - categorical_accuracy: 0.9453
# Epoch 77/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3056 - categorical_accuracy: 0.9023
# Epoch 78/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1380 - categorical_accuracy: 0.9492
# Epoch 79/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0594 - categorical_accuracy: 0.9766
# Epoch 80/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0488 - categorical_accuracy: 0.9883
# Epoch 81/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0749 - categorical_accuracy: 0.9688
# Epoch 82/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2661 - categorical_accuracy: 0.9141
# Epoch 83/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2548 - categorical_accuracy: 0.8789
# Epoch 84/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2202 - categorical_accuracy: 0.8945
# Epoch 85/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1226 - categorical_accuracy: 0.9727
# Epoch 86/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0611 - categorical_accuracy: 0.9883
# Epoch 87/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0319 - categorical_accuracy: 0.9961
# Epoch 88/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0190 - categorical_accuracy: 0.9961
# Epoch 89/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0122 - categorical_accuracy: 1.0000
# Epoch 90/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0127 - categorical_accuracy: 0.9961
# Epoch 91/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0255 - categorical_accuracy: 0.9961
# Epoch 92/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0333 - categorical_accuracy: 0.9844
# Epoch 93/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0311 - categorical_accuracy: 0.9883
# Epoch 94/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0322 - categorical_accuracy: 0.9805
# Epoch 95/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0661 - categorical_accuracy: 0.9766
# Epoch 96/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2558 - categorical_accuracy: 0.9258
# Epoch 97/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1495 - categorical_accuracy: 0.9609
# Epoch 98/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1051 - categorical_accuracy: 0.9688
# Epoch 99/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0564 - categorical_accuracy: 0.9766
# Epoch 100/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0737 - categorical_accuracy: 0.9727
# Epoch 101/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1011 - categorical_accuracy: 0.9609
# Epoch 102/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0450 - categorical_accuracy: 0.9766
# Epoch 103/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0139 - categorical_accuracy: 0.9961
# Epoch 104/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0067 - categorical_accuracy: 1.0000
# Epoch 105/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0065 - categorical_accuracy: 1.0000
# Epoch 106/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0220 - categorical_accuracy: 0.9844
# Epoch 107/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0207 - categorical_accuracy: 0.9922
# Epoch 108/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0167 - categorical_accuracy: 0.9922
# Epoch 109/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 110/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0177 - categorical_accuracy: 0.9961
# Epoch 111/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0084 - categorical_accuracy: 0.9961
# Epoch 112/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0108 - categorical_accuracy: 0.9961
# Epoch 113/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0161 - categorical_accuracy: 0.9961
# Epoch 114/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0169 - categorical_accuracy: 0.9922
# Epoch 115/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0247 - categorical_accuracy: 0.9883
# Epoch 116/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0596 - categorical_accuracy: 0.9805
# Epoch 117/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0551 - categorical_accuracy: 0.9805
# Epoch 118/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0270 - categorical_accuracy: 0.9922
# Epoch 119/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0489 - categorical_accuracy: 0.9805
# Epoch 120/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.3301 - categorical_accuracy: 0.8555
# Epoch 121/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.3296 - categorical_accuracy: 0.6367
# Epoch 122/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.8310 - categorical_accuracy: 0.6406
# Epoch 123/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6512 - categorical_accuracy: 0.7656
# Epoch 124/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.4578 - categorical_accuracy: 0.7969
# Epoch 125/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3911 - categorical_accuracy: 0.8164
# Epoch 126/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2791 - categorical_accuracy: 0.9141
# Epoch 127/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2846 - categorical_accuracy: 0.9102
# Epoch 128/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2408 - categorical_accuracy: 0.9023
# Epoch 129/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2182 - categorical_accuracy: 0.9102
# Epoch 130/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5970 - categorical_accuracy: 0.7188
# Epoch 131/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.4390 - categorical_accuracy: 0.8164
# Epoch 132/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2792 - categorical_accuracy: 0.9023
# Epoch 133/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2204 - categorical_accuracy: 0.9648
# Epoch 134/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3042 - categorical_accuracy: 0.8945
# Epoch 135/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2903 - categorical_accuracy: 0.8711
# Epoch 136/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2306 - categorical_accuracy: 0.9492
# Epoch 137/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1430 - categorical_accuracy: 0.9570
# Epoch 138/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1680 - categorical_accuracy: 0.9414
# Epoch 139/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.8719 - categorical_accuracy: 0.7812
# Epoch 140/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.7282 - categorical_accuracy: 0.7148
# Epoch 141/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5334 - categorical_accuracy: 0.7812
# Epoch 142/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4847 - categorical_accuracy: 0.7930
# Epoch 143/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3581 - categorical_accuracy: 0.8867
# Epoch 144/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2755 - categorical_accuracy: 0.9141
# Epoch 145/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2156 - categorical_accuracy: 0.9297
# Epoch 146/255
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1524 - categorical_accuracy: 0.9531
# Epoch 147/255
# 8/8 [==============================] - 1s 80ms/step - loss: 1.1807 - categorical_accuracy: 0.7422
# Epoch 148/255
# 8/8 [==============================] - 1s 79ms/step - loss: 1.4685 - categorical_accuracy: 0.5742
# Epoch 149/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0798 - categorical_accuracy: 0.5469
# Epoch 150/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.8470 - categorical_accuracy: 0.6328
# Epoch 151/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4871 - categorical_accuracy: 0.7891
# Epoch 152/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3627 - categorical_accuracy: 0.8789
# Epoch 153/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2645 - categorical_accuracy: 0.9102
# Epoch 154/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2474 - categorical_accuracy: 0.9102
# Epoch 155/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3762 - categorical_accuracy: 0.8633
# Epoch 156/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3113 - categorical_accuracy: 0.8867
# Epoch 157/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2971 - categorical_accuracy: 0.9023
# Epoch 158/255
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1876 - categorical_accuracy: 0.9492
# Epoch 159/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2026 - categorical_accuracy: 0.9258
# Epoch 160/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1463 - categorical_accuracy: 0.9531
# Epoch 161/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1405 - categorical_accuracy: 0.9492
# Epoch 162/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1601 - categorical_accuracy: 0.9414
# Epoch 163/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1097 - categorical_accuracy: 0.9727
# Epoch 164/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1061 - categorical_accuracy: 0.9570
# Epoch 165/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2431 - categorical_accuracy: 0.9258
# Epoch 166/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1530 - categorical_accuracy: 0.9414
# Epoch 167/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1042 - categorical_accuracy: 0.9609
# Epoch 168/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1573 - categorical_accuracy: 0.9336
# Epoch 169/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1294 - categorical_accuracy: 0.9375
# Epoch 170/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3078 - categorical_accuracy: 0.9336
# Epoch 171/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1919 - categorical_accuracy: 0.9414
# Epoch 172/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2613 - categorical_accuracy: 0.9023
# Epoch 173/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1922 - categorical_accuracy: 0.9453
# Epoch 174/255
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1045 - categorical_accuracy: 0.9648
# Epoch 175/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0971 - categorical_accuracy: 0.9766
# Epoch 176/255
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0617 - categorical_accuracy: 0.9883
# Epoch 177/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0375 - categorical_accuracy: 0.9883
# Epoch 178/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0210 - categorical_accuracy: 1.0000
# Epoch 179/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0131 - categorical_accuracy: 1.0000
# Epoch 180/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 181/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 182/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 183/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 184/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 185/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0307 - categorical_accuracy: 0.9883
# Epoch 186/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1014 - categorical_accuracy: 0.9648
# Epoch 187/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2078 - categorical_accuracy: 0.9336
# Epoch 188/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1715 - categorical_accuracy: 0.9531
# Epoch 189/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2495 - categorical_accuracy: 0.9297
# Epoch 190/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1844 - categorical_accuracy: 0.9375
# Epoch 191/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1107 - categorical_accuracy: 0.9688
# Epoch 192/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0639 - categorical_accuracy: 0.9883
# Epoch 193/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0436 - categorical_accuracy: 0.9922
# Epoch 194/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0319 - categorical_accuracy: 0.9961
# Epoch 195/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0202 - categorical_accuracy: 1.0000
# Epoch 196/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0204 - categorical_accuracy: 1.0000
# Epoch 197/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 198/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 199/255
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 200/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0065 - categorical_accuracy: 1.0000
# Epoch 201/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0059 - categorical_accuracy: 0.9961
# Epoch 202/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 203/255
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 204/255
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 205/255
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 206/255
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 207/255
# 8/8 [==============================] - 1s 73ms/step - loss: 9.9729e-04 - categorical_accuracy: 1.0000
# Epoch 208/255
# 8/8 [==============================] - 1s 72ms/step - loss: 9.2418e-04 - categorical_accuracy: 1.0000
# Epoch 209/255
# 8/8 [==============================] - 1s 73ms/step - loss: 8.6628e-04 - categorical_accuracy: 1.0000
# Epoch 210/255
# 8/8 [==============================] - 1s 71ms/step - loss: 7.8971e-04 - categorical_accuracy: 1.0000
# Epoch 211/255
# 8/8 [==============================] - 1s 72ms/step - loss: 7.4638e-04 - categorical_accuracy: 1.0000
# Epoch 212/255
# 8/8 [==============================] - 1s 74ms/step - loss: 7.0031e-04 - categorical_accuracy: 1.0000
# Epoch 213/255
# 8/8 [==============================] - 1s 72ms/step - loss: 6.5669e-04 - categorical_accuracy: 1.0000
# Epoch 214/255
# 8/8 [==============================] - 1s 73ms/step - loss: 6.2110e-04 - categorical_accuracy: 1.0000
# Epoch 215/255
# 8/8 [==============================] - 1s 72ms/step - loss: 5.8476e-04 - categorical_accuracy: 1.0000
# Epoch 216/255
# 8/8 [==============================] - 1s 72ms/step - loss: 5.5700e-04 - categorical_accuracy: 1.0000
# Epoch 217/255
# 8/8 [==============================] - 1s 72ms/step - loss: 5.1814e-04 - categorical_accuracy: 1.0000
# Epoch 218/255
# 8/8 [==============================] - 1s 72ms/step - loss: 4.9073e-04 - categorical_accuracy: 1.0000
# Epoch 219/255
# 8/8 [==============================] - 1s 71ms/step - loss: 4.6976e-04 - categorical_accuracy: 1.0000
# Epoch 220/255
# 8/8 [==============================] - 1s 72ms/step - loss: 4.4719e-04 - categorical_accuracy: 1.0000
# Epoch 221/255
# 8/8 [==============================] - 1s 71ms/step - loss: 4.3092e-04 - categorical_accuracy: 1.0000
# Epoch 222/255
# 8/8 [==============================] - 1s 71ms/step - loss: 4.1151e-04 - categorical_accuracy: 1.0000
# Epoch 223/255
# 8/8 [==============================] - 1s 72ms/step - loss: 3.8668e-04 - categorical_accuracy: 1.0000
# Epoch 224/255
# 8/8 [==============================] - 1s 71ms/step - loss: 3.6854e-04 - categorical_accuracy: 1.0000
# Epoch 225/255
# 8/8 [==============================] - 1s 71ms/step - loss: 3.5576e-04 - categorical_accuracy: 1.0000
# Epoch 226/255
# 8/8 [==============================] - 1s 72ms/step - loss: 3.4155e-04 - categorical_accuracy: 1.0000
# Epoch 227/255
# 8/8 [==============================] - 1s 71ms/step - loss: 3.2530e-04 - categorical_accuracy: 1.0000
# Epoch 228/255
# 8/8 [==============================] - 1s 72ms/step - loss: 3.1366e-04 - categorical_accuracy: 1.0000
# Epoch 229/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.9995e-04 - categorical_accuracy: 1.0000
# Epoch 230/255
# 8/8 [==============================] - 1s 73ms/step - loss: 2.8508e-04 - categorical_accuracy: 1.0000
# Epoch 231/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.7611e-04 - categorical_accuracy: 1.0000
# Epoch 232/255
# 8/8 [==============================] - 1s 73ms/step - loss: 2.6601e-04 - categorical_accuracy: 1.0000
# Epoch 233/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.5525e-04 - categorical_accuracy: 1.0000
# Epoch 234/255
# 8/8 [==============================] - 1s 72ms/step - loss: 2.4474e-04 - categorical_accuracy: 1.0000
# Epoch 235/255
# 8/8 [==============================] - 1s 72ms/step - loss: 2.3833e-04 - categorical_accuracy: 1.0000
# Epoch 236/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.2998e-04 - categorical_accuracy: 1.0000
# Epoch 237/255
# 8/8 [==============================] - 1s 72ms/step - loss: 2.2191e-04 - categorical_accuracy: 1.0000
# Epoch 238/255
# 8/8 [==============================] - 1s 71ms/step - loss: 2.1214e-04 - categorical_accuracy: 1.0000
# Epoch 239/255
# 8/8 [==============================] - 1s 72ms/step - loss: 2.0788e-04 - categorical_accuracy: 1.0000
# Epoch 240/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.9976e-04 - categorical_accuracy: 1.0000
# Epoch 241/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.9593e-04 - categorical_accuracy: 1.0000
# Epoch 242/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.8831e-04 - categorical_accuracy: 1.0000
# Epoch 243/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.8217e-04 - categorical_accuracy: 1.0000
# Epoch 244/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.7877e-04 - categorical_accuracy: 1.0000
# Epoch 245/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.7430e-04 - categorical_accuracy: 1.0000
# Epoch 246/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.6862e-04 - categorical_accuracy: 1.0000
# Epoch 247/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.6556e-04 - categorical_accuracy: 1.0000
# Epoch 248/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.5951e-04 - categorical_accuracy: 1.0000
# Epoch 249/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.5567e-04 - categorical_accuracy: 1.0000
# Epoch 250/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.5282e-04 - categorical_accuracy: 1.0000
# Epoch 251/255
# 8/8 [==============================] - 1s 73ms/step - loss: 1.4705e-04 - categorical_accuracy: 1.0000
# Epoch 252/255
# 8/8 [==============================] - 1s 72ms/step - loss: 1.4352e-04 - categorical_accuracy: 1.0000
# Epoch 253/255
# 8/8 [==============================] - 1s 71ms/step - loss: 1.4081e-04 - categorical_accuracy: 1.0000
# Epoch 254/255
# 8/8 [==============================] - 1s 70ms/step - loss: 1.3667e-04 - categorical_accuracy: 1.0000
# Epoch 255/255
# 8/8 [==============================] - 1s 69ms/step - loss: 1.3500e-04 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 30, 64)            442112
#
#  lstm_20 (LSTM)              (None, 30, 128)           98816
#
#  lstm_21 (LSTM)              (None, 64)                49408
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dense_20 (Dense)            (None, 9)                 297
#
# =================================================================
# Total params: 596873 (2.28 MB)
# Trainable params: 596873 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 518ms/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'hello'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('D:\\ML_Project_Final\\action.h5')
# Out:
# D:\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
del model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Define the model architecture
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# Load weights from the file
model.load_weights('D:\\ML_Project_Final\\action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 297 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA33B8B880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 492ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[13,  0],
#         [ 0,  1]],
#
#        [[11,  0],
#         [ 0,  3]],
#
#        [[12,  0],
#         [ 0,  2]],
#
#        [[10,  0],
#         [ 0,  4]],
#
#        [[13,  0],
#         [ 0,  1]],
#
#        [[13,  0],
#         [ 0,  1]],
#
#        [[12,  0],
#         [ 0,  2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245),(255, 0, 0), (0, 255, 0),(255, 255, 0), (255, 0, 255),(128, 128, 128), (0, 128, 0)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))


        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res):
                if res[np.argmax(res)] > threshold:

                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)

        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# danger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# ...
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thankyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# me
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# police
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# call
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# call

# %%
import cv2
import numpy as np
import requests
import mediapipe as mp

# Assuming you have already defined the necessary functions and model
# ...
sequence = []
sentence = []
predictions = []
threshold = 0.5

# Set up Pushover credentials
api_token = 'av48uwk6ic2oheyyjf44phrt47q5dz'
user_key = 'ugw9227sfr8ih35wrejgaku7533sbe'


# Define the sequences of actions you want to detect
target_sequences = [['call', 'police'], ['help', 'me'],['danger','call','police']]

# Initialize variables for sequential action detection
sequence_actions = []
sequence_threshold = max(len(seq) for seq in target_sequences)

def send_pushover_notification(message):
    url = "https://api.pushover.net/1/messages.json"
    data = {
        "token": api_token,
        "user": user_key,
        "message": message,
    }
    requests.post(url, data=data)

cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        draw_styled_landmarks(image, results)

        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            action_index = np.argmax(res)
            print(actions[action_index])
            predictions.append(action_index)

            # Sequential action detection logic
            sequence_actions.append(actions[action_index])
            sequence_actions = sequence_actions[-sequence_threshold:]

            # Check if any of the target sequences is detected
            for target_sequence in target_sequences:
                if len(sequence_actions) == sequence_threshold and all(
                        action in sequence_actions for action in target_sequence):
                    # Send Pushover notification
                    message = f"Camera action detected: {'  '.join(target_sequence)} + call 911."
                    send_pushover_notification(message)

            # Viz logic
            if np.unique(predictions[-10:])[0] == action_index:
                if res[action_index] > threshold:
                    if len(sentence) > 0:
                        if actions[action_index] != sentence[-1]:
                            sentence.append(actions[action_index])
                    else:
                        sentence.append(actions[action_index])

            if len(sentence) > 5:
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)

        cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
